# %%
import pandas as pd

# Leer el archivo CSV
df = pd.read_csv('usuarios_sinteticos.csv')

# Obtener la cantidad de registros
cantidad_registros = len(df)

print(df.head())

print(f"Cantidad de registros en el CSV: {cantidad_registros}")
# Out:
#        nombre apellido_paterno apellido_materno                curp  \
# 0     Elizama          Qlmeida          Berdeja  QEBE760320MBSLBL59
# 1      Susilu          Barnard           Tuhabi  BATS830125MOCRTS86
# 2      Maroto         Sandovsl             Vazm  SAVM890913HCMNVM53
# 3     Redorta            Puppo         Beccerra  PUBR010607HMSPBRR0
# 4  Xtrychnine        Manzanita             Gava  MAGX600101MDFNGX26
#
#              rfc                           email    telefono  edad
# 0  QEBE760320LBL            vadhir@inyecteck.com  6158056020    50
# 1  BATS830125RTS  ledezgon@impactografico.com.mx  2875343902    65
# 2  SAVM890913NVM             joselito@hotmeil.es  3149152513    74
# 3  PUBR010607PBR           volker@todoretail.com  7356088743    79
# 4  MAGX600101NGX            yane@jjmetals.com.mx  5558056573    77
# Cantidad de registros en el CSV: 1983800

# %%
import pandas as pd

df = pd.read_csv("usuarios_sinteticos.csv")

print("Total:", len(df))
print("CURP únicos:", df["curp"].nunique())
print("RFC únicos:", df["rfc"].nunique())
print("Email únicos:", df["email"].nunique())
# Out:
# Total: 1983800
# CURP únicos: 1983798
# RFC únicos: 1973767
# Email únicos: 9919
